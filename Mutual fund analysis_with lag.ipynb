# %% [markdown]
# # Load mutual fund return data from csv

# %%
# Import all the packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from matplotlib.ticker import FuncFormatter
import sklearn.linear_model as lm
import statsmodels.api as sm
from tqdm.notebook import trange, tqdm

# %%
# Read data into dataframe
## Read the data with the 500 funds through time with only funds that contain management fees and turnover data
data = pd.read_csv('fund_data_largest_500_with_fees.csv')

# Convert the 'caldt' to a Python datetime and then to the Fama-French date format (YYYYMM)
data['Date'] = pd.to_datetime(data['caldt'], format="%Y%m%d")
data['YYYYMM'] = data['Date'].dt.strftime('%Y%m').astype(int)

# Set multi-column index (YYYYMM and crsp_fundno), but keep original columns
data.set_index(['YYYYMM','crsp_fundno'], drop=False, inplace=True)

# Print the top 3 rows
# print(data.head(3))
# print(data.columns)
# data.head(10).to_excel('Quick sample for inspection.xlsx')
# data.head()

# %% [markdown]
# # Load the Fama-French series

# %%
#  Load the 5 Factor into dataframe
famafrench = pd.read_csv('F-F_Research_Data_5_Factors_2x3.CSV', index_col=0, skiprows=3)

#  Load the 5 Factor into dataframe
momentum = pd.read_csv('F-F_Momentum_Factor.CSV', skiprows=13, index_col=0)

# Left-join the momentum dataframe to the famafrench dataframe
famafrench = famafrench.merge(momentum, left_index=True, right_index=True, how='left')

# Only select CAPM, Fama-French 3 models and 4-factors Carhart model
#famafrench = famafrench[['Mkt-RF', 'SMB', 'HML', 'RF', 'Mom']]

# Rename the momentum column to "WML"
famafrench.rename(columns={"Mom":"WML"}, inplace=True)

# Make returns into decimals instead of percentages
famafrench = famafrench / 100
display(famafrench)
# Out:
#         Mkt-RF     SMB     HML     RMW     CMA      RF     WML
# 196307 -0.0039 -0.0045 -0.0094  0.0066 -0.0115  0.0027  0.0100
# 196308  0.0507 -0.0082  0.0182  0.0040 -0.0040  0.0025  0.0103
# 196309 -0.0157 -0.0048  0.0017 -0.0076  0.0024  0.0027  0.0016
# 196310  0.0253 -0.0130 -0.0004  0.0275 -0.0224  0.0029  0.0314
# 196311 -0.0085 -0.0085  0.0170 -0.0045  0.0222  0.0027 -0.0075
# ...        ...     ...     ...     ...     ...     ...     ...
# 202008  0.0763 -0.0094 -0.0294  0.0427 -0.0144  0.0001  0.0051
# 202009 -0.0363  0.0007 -0.0251 -0.0115 -0.0177  0.0001  0.0305
# 202010 -0.0210  0.0476  0.0403 -0.0060 -0.0053  0.0001 -0.0303
# 202011  0.1247  0.0675  0.0211 -0.0278  0.0105  0.0001 -0.1225
# 202012  0.0463  0.0474 -0.0146 -0.0216 -0.0008  0.0001 -0.0234
#
# [690 rows x 7 columns]

# %% [markdown]
# ### Fama-French cumulative return plot (after 2000)

# %%
# Get sample period
famafrench_sample = famafrench[famafrench.index > 199912]

# Calculate cumulative returns on the dataframe
#famafrench_cumprod = np.cumprod(1 + famafrench_sample, axis=0) - 1   # Cumulative ARITHMETIC returns
famafrench_cumprod = np.cumsum(np.log(1 + famafrench_sample), axis=0)  # Cumulative LOG returns

# Add Python datetime to the dataframe (new column called "Date")
famafrench_cumprod['Date'] = pd.to_datetime(famafrench_sample.index, format="%Y%m")

# Plot the cumulative fama-french factors over time
# figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
# plt.plot(famafrench_cumprod['Date'], famafrench_cumprod[['Mkt-RF','SMB','HML','RF','WML','RMW','CMA']])
# plt.title('Cumulative log returns over time')
# plt.legend(['Market','Size','Value','Riskfree','Momentum', 'Profitability', 'Investments'])
# plt.xlabel('Time (months)')
# plt.ylabel('Log cumulative returns')
# plt.show()

# %% [markdown]
# # Adding new variables to the mutual funds based on rolling windows
#
# ### Calculating the 1-year alpha, market beta, HML beta, 12-month returns for each fund at each month

# %%
# Initialize list that is going to keep track of all our results
# I'm using a list here because that is the fastest object in Python!
# I also tried to directly save the results to the 'data' dataframe inside of the loops but that was 4x slower.
results = []

# Specify type of model
reg = lm.LinearRegression()

# Get the string representation of the months starting in 1992
dates = famafrench.index[famafrench.index >= 199200].unique()

# Starting index
lookback = 12            # Lookback period is 12 months (or 3 months)

# Loop over the dates
for period in trange(lookback, len(dates)):
    
    # Get the current date
    current_date = dates[period]
    
    # Get all dates of 36 months ago until last month
    lookback_period = dates[period-lookback:period]
    
    # Print some information
    print('Iteration {} at date {}, lookback period is {} to {} ({:.0f} months)'.format(
        period, current_date, lookback_period[0], lookback_period[-1], len(lookback_period)))

    # Get corresponding Fama-French data
    ff_history_index = famafrench.index.isin(lookback_period)
    ff_history = famafrench.loc[ff_history_index]
    
    # Get all funds at this period in time (in this iteration)
    funds_this_period_index = data.index.get_level_values('YYYYMM') == current_date
    funds_this_period = data.loc[funds_this_period_index, 'crsp_fundno'].unique()
    
    # Get all historical data for the funds that exist in this period in time
    funds_historical_data_index = np.logical_and(
        data.index.get_level_values('YYYYMM').isin(lookback_period),
        data.index.get_level_values('crsp_fundno').isin(funds_this_period)
    )
    funds_historical_data = data.loc[funds_historical_data_index]
    
    # Loop over all funds THIS PERIOD
    for fund in funds_this_period:
        
        # Get the row positions for the data for this fund   
        fund_data_index = funds_historical_data.index.get_level_values('crsp_fundno') == fund
        
        # Get the individual data for this fund
        # And make new index that corresponds to the ff_history index (this makes the merge below faster!)
        fund_data = funds_historical_data.loc[fund_data_index].set_index('YYYYMM')
        
        # If this specific fund has less than 25 observations, ignore it! For 1 month lookback, change this to 2
        if fund_data.shape[0] < 12:
            continue
        
        # Join the regression data together
        reg_data = ff_history.merge(fund_data['mret'], left_index=True, right_index=True, how='left')
        
        # Calculate the fund returns over the previous 12 months (or less)
        ret_12_months = np.product(1 + reg_data.tail(12)['mret']) - 1
        
        # Remove rows with no data
        reg_data = reg_data.dropna()
        
        # Calculate excess returns for the fund
        reg_data['Excess fund return'] = reg_data['mret'] - reg_data['RF']
            
        # Get the x-values for the regression
        x = reg_data[['Mkt-RF','HML']].values.reshape(reg_data.shape[0], 2)
        
        # Get the y-values for the regression
        y = reg_data['Excess fund return'].values.reshape(reg_data.shape[0], 1)
        
        # Fit regression
        reg.fit(x, y)
        
        # Append the calculations to our 'results' list
        # Note that the order in which we save the results matters! (see comment with [!!!] at the bottom of this code)
        
        #                 YYYYMM   crsp_fundno     Alpha        Market beta        HML beta        12M return
        #                    v          v            v               v                v                v
        #                    v          v            v               v                v                v
        results.append([current_date, fund, reg.intercept_[0], reg.coef_[0][0], reg.coef_[0][1], ret_12_months])

# This is the end of the loops

# We now turn our 'results' list into a dataframe (so we can merge it with the 'data' dataframe below)
# [!!!] Note that we need to specify the order of the results using (the correct) column names
results = pd.DataFrame(results, columns=['YYYYMM','crsp_fundno','Alpha','Market beta','HML beta','12M return'])

# Create multi-index (so it matches the 'data' dataframe index)
results.set_index(['YYYYMM','crsp_fundno'], inplace=True)

# Final step: merge our results back into the original 'data' dataframe. The matching is done based on the multi-index!
data = data.merge(results, left_index=True, right_index=True, how='left')

# DONE! 
# We just added new data to each fund at each moment in time based on historical (36-month) regressions!+b

print('Done.')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=336.0), HTML(value='')))
# Iteration 12 at date 199301, lookback period is 199201 to 199212 (12 months)
# Iteration 13 at date 199302, lookback period is 199202 to 199301 (12 months)
# Iteration 14 at date 199303, lookback period is 199203 to 199302 (12 months)
# Iteration 15 at date 199304, lookback period is 199204 to 199303 (12 months)
# Iteration 16 at date 199305, lookback period is 199205 to 199304 (12 months)
# Iteration 17 at date 199306, lookback period is 199206 to 199305 (12 months)
# Iteration 18 at date 199307, lookback period is 199207 to 199306 (12 months)
# Iteration 19 at date 199308, lookback period is 199208 to 199307 (12 months)
# Iteration 20 at date 199309, lookback period is 199209 to 199308 (12 months)
# Iteration 21 at date 199310, lookback period is 199210 to 199309 (12 months)
# Iteration 22 at date 199311, lookback period is 199211 to 199310 (12 months)
# Iteration 23 at date 199312, lookback period is 199212 to 199311 (12 months)
# Iteration 24 at date 199401, lookback period is 199301 to 199312 (12 months)
# Iteration 25 at date 199402, lookback period is 199302 to 199401 (12 months)
# Iteration 26 at date 199403, lookback period is 199303 to 199402 (12 months)
# Iteration 27 at date 199404, lookback period is 199304 to 199403 (12 months)
# Iteration 28 at date 199405, lookback period is 199305 to 199404 (12 months)
# Iteration 29 at date 199406, lookback period is 199306 to 199405 (12 months)
# Iteration 30 at date 199407, lookback period is 199307 to 199406 (12 months)
# Iteration 31 at date 199408, lookback period is 199308 to 199407 (12 months)
# Iteration 32 at date 199409, lookback period is 199309 to 199408 (12 months)
# Iteration 33 at date 199410, lookback period is 199310 to 199409 (12 months)
# Iteration 34 at date 199411, lookback period is 199311 to 199410 (12 months)
# Iteration 35 at date 199412, lookback period is 199312 to 199411 (12 months)
# Iteration 36 at date 199501, lookback period is 199401 to 199412 (12 months)
# Iteration 37 at date 199502, lookback period is 199402 to 199501 (12 months)
# Iteration 38 at date 199503, lookback period is 199403 to 199502 (12 months)
# Iteration 39 at date 199504, lookback period is 199404 to 199503 (12 months)
# Iteration 40 at date 199505, lookback period is 199405 to 199504 (12 months)
# Iteration 41 at date 199506, lookback period is 199406 to 199505 (12 months)
# Iteration 42 at date 199507, lookback period is 199407 to 199506 (12 months)
# Iteration 43 at date 199508, lookback period is 199408 to 199507 (12 months)
# Iteration 44 at date 199509, lookback period is 199409 to 199508 (12 months)
# Iteration 45 at date 199510, lookback period is 199410 to 199509 (12 months)
# Iteration 46 at date 199511, lookback period is 199411 to 199510 (12 months)
# Iteration 47 at date 199512, lookback period is 199412 to 199511 (12 months)
# Iteration 48 at date 199601, lookback period is 199501 to 199512 (12 months)
# Iteration 49 at date 199602, lookback period is 199502 to 199601 (12 months)
# Iteration 50 at date 199603, lookback period is 199503 to 199602 (12 months)
# Iteration 51 at date 199604, lookback period is 199504 to 199603 (12 months)
# Iteration 52 at date 199605, lookback period is 199505 to 199604 (12 months)
# Iteration 53 at date 199606, lookback period is 199506 to 199605 (12 months)
# Iteration 54 at date 199607, lookback period is 199507 to 199606 (12 months)
# Iteration 55 at date 199608, lookback period is 199508 to 199607 (12 months)
# Iteration 56 at date 199609, lookback period is 199509 to 199608 (12 months)
# Iteration 57 at date 199610, lookback period is 199510 to 199609 (12 months)
# Iteration 58 at date 199611, lookback period is 199511 to 199610 (12 months)
# Iteration 59 at date 199612, lookback period is 199512 to 199611 (12 months)
# Iteration 60 at date 199701, lookback period is 199601 to 199612 (12 months)
# Iteration 61 at date 199702, lookback period is 199602 to 199701 (12 months)
# Iteration 62 at date 199703, lookback period is 199603 to 199702 (12 months)
# Iteration 63 at date 199704, lookback period is 199604 to 199703 (12 months)
# Iteration 64 at date 199705, lookback period is 199605 to 199704 (12 months)
# Iteration 65 at date 199706, lookback period is 199606 to 199705 (12 months)
# Iteration 66 at date 199707, lookback period is 199607 to 199706 (12 months)
# Iteration 67 at date 199708, lookback period is 199608 to 199707 (12 months)
# Iteration 68 at date 199709, lookback period is 199609 to 199708 (12 months)
# Iteration 69 at date 199710, lookback period is 199610 to 199709 (12 months)
# Iteration 70 at date 199711, lookback period is 199611 to 199710 (12 months)
# Iteration 71 at date 199712, lookback period is 199612 to 199711 (12 months)
# Iteration 72 at date 199801, lookback period is 199701 to 199712 (12 months)
# Iteration 73 at date 199802, lookback period is 199702 to 199801 (12 months)
# Iteration 74 at date 199803, lookback period is 199703 to 199802 (12 months)
# Iteration 75 at date 199804, lookback period is 199704 to 199803 (12 months)
# Iteration 76 at date 199805, lookback period is 199705 to 199804 (12 months)
# Iteration 77 at date 199806, lookback period is 199706 to 199805 (12 months)
# Iteration 78 at date 199807, lookback period is 199707 to 199806 (12 months)
# Iteration 79 at date 199808, lookback period is 199708 to 199807 (12 months)
# Iteration 80 at date 199809, lookback period is 199709 to 199808 (12 months)
# Iteration 81 at date 199810, lookback period is 199710 to 199809 (12 months)
# Iteration 82 at date 199811, lookback period is 199711 to 199810 (12 months)
# Iteration 83 at date 199812, lookback period is 199712 to 199811 (12 months)
# Iteration 84 at date 199901, lookback period is 199801 to 199812 (12 months)
# Iteration 85 at date 199902, lookback period is 199802 to 199901 (12 months)
# Iteration 86 at date 199903, lookback period is 199803 to 199902 (12 months)
# Iteration 87 at date 199904, lookback period is 199804 to 199903 (12 months)
# Iteration 88 at date 199905, lookback period is 199805 to 199904 (12 months)
# Iteration 89 at date 199906, lookback period is 199806 to 199905 (12 months)
# Iteration 90 at date 199907, lookback period is 199807 to 199906 (12 months)
# Iteration 91 at date 199908, lookback period is 199808 to 199907 (12 months)
# Iteration 92 at date 199909, lookback period is 199809 to 199908 (12 months)
# Iteration 93 at date 199910, lookback period is 199810 to 199909 (12 months)
# Iteration 94 at date 199911, lookback period is 199811 to 199910 (12 months)
# Iteration 95 at date 199912, lookback period is 199812 to 199911 (12 months)
# Iteration 96 at date 200001, lookback period is 199901 to 199912 (12 months)
# Iteration 97 at date 200002, lookback period is 199902 to 200001 (12 months)
# Iteration 98 at date 200003, lookback period is 199903 to 200002 (12 months)
# Iteration 99 at date 200004, lookback period is 199904 to 200003 (12 months)
# Iteration 100 at date 200005, lookback period is 199905 to 200004 (12 months)
# Iteration 101 at date 200006, lookback period is 199906 to 200005 (12 months)
# Iteration 102 at date 200007, lookback period is 199907 to 200006 (12 months)
# Iteration 103 at date 200008, lookback period is 199908 to 200007 (12 months)
# Iteration 104 at date 200009, lookback period is 199909 to 200008 (12 months)
# Iteration 105 at date 200010, lookback period is 199910 to 200009 (12 months)
# Iteration 106 at date 200011, lookback period is 199911 to 200010 (12 months)
# Iteration 107 at date 200012, lookback period is 199912 to 200011 (12 months)
# Iteration 108 at date 200101, lookback period is 200001 to 200012 (12 months)
# Iteration 109 at date 200102, lookback period is 200002 to 200101 (12 months)
# Iteration 110 at date 200103, lookback period is 200003 to 200102 (12 months)
# Iteration 111 at date 200104, lookback period is 200004 to 200103 (12 months)
# Iteration 112 at date 200105, lookback period is 200005 to 200104 (12 months)
# Iteration 113 at date 200106, lookback period is 200006 to 200105 (12 months)
# Iteration 114 at date 200107, lookback period is 200007 to 200106 (12 months)
# Iteration 115 at date 200108, lookback period is 200008 to 200107 (12 months)
# Iteration 116 at date 200109, lookback period is 200009 to 200108 (12 months)
# Iteration 117 at date 200110, lookback period is 200010 to 200109 (12 months)
# Iteration 118 at date 200111, lookback period is 200011 to 200110 (12 months)
# Iteration 119 at date 200112, lookback period is 200012 to 200111 (12 months)
# Iteration 120 at date 200201, lookback period is 200101 to 200112 (12 months)
# Iteration 121 at date 200202, lookback period is 200102 to 200201 (12 months)
# Iteration 122 at date 200203, lookback period is 200103 to 200202 (12 months)
# Iteration 123 at date 200204, lookback period is 200104 to 200203 (12 months)
# Iteration 124 at date 200205, lookback period is 200105 to 200204 (12 months)
# Iteration 125 at date 200206, lookback period is 200106 to 200205 (12 months)
# Iteration 126 at date 200207, lookback period is 200107 to 200206 (12 months)
# Iteration 127 at date 200208, lookback period is 200108 to 200207 (12 months)
# Iteration 128 at date 200209, lookback period is 200109 to 200208 (12 months)
# Iteration 129 at date 200210, lookback period is 200110 to 200209 (12 months)
# Iteration 130 at date 200211, lookback period is 200111 to 200210 (12 months)
# Iteration 131 at date 200212, lookback period is 200112 to 200211 (12 months)
# Iteration 132 at date 200301, lookback period is 200201 to 200212 (12 months)
# Iteration 133 at date 200302, lookback period is 200202 to 200301 (12 months)
# Iteration 134 at date 200303, lookback period is 200203 to 200302 (12 months)
# Iteration 135 at date 200304, lookback period is 200204 to 200303 (12 months)
# Iteration 136 at date 200305, lookback period is 200205 to 200304 (12 months)
# Iteration 137 at date 200306, lookback period is 200206 to 200305 (12 months)
# Iteration 138 at date 200307, lookback period is 200207 to 200306 (12 months)
# Iteration 139 at date 200308, lookback period is 200208 to 200307 (12 months)
# Iteration 140 at date 200309, lookback period is 200209 to 200308 (12 months)
# Iteration 141 at date 200310, lookback period is 200210 to 200309 (12 months)
# Iteration 142 at date 200311, lookback period is 200211 to 200310 (12 months)
# Iteration 143 at date 200312, lookback period is 200212 to 200311 (12 months)
# Iteration 144 at date 200401, lookback period is 200301 to 200312 (12 months)
# Iteration 145 at date 200402, lookback period is 200302 to 200401 (12 months)
# Iteration 146 at date 200403, lookback period is 200303 to 200402 (12 months)
# Iteration 147 at date 200404, lookback period is 200304 to 200403 (12 months)
# Iteration 148 at date 200405, lookback period is 200305 to 200404 (12 months)
# Iteration 149 at date 200406, lookback period is 200306 to 200405 (12 months)
# Iteration 150 at date 200407, lookback period is 200307 to 200406 (12 months)
# Iteration 151 at date 200408, lookback period is 200308 to 200407 (12 months)
# Iteration 152 at date 200409, lookback period is 200309 to 200408 (12 months)
# Iteration 153 at date 200410, lookback period is 200310 to 200409 (12 months)
# Iteration 154 at date 200411, lookback period is 200311 to 200410 (12 months)
# Iteration 155 at date 200412, lookback period is 200312 to 200411 (12 months)
# Iteration 156 at date 200501, lookback period is 200401 to 200412 (12 months)
# Iteration 157 at date 200502, lookback period is 200402 to 200501 (12 months)
# Iteration 158 at date 200503, lookback period is 200403 to 200502 (12 months)
# Iteration 159 at date 200504, lookback period is 200404 to 200503 (12 months)
# Iteration 160 at date 200505, lookback period is 200405 to 200504 (12 months)
# Iteration 161 at date 200506, lookback period is 200406 to 200505 (12 months)
# Iteration 162 at date 200507, lookback period is 200407 to 200506 (12 months)
# Iteration 163 at date 200508, lookback period is 200408 to 200507 (12 months)
# Iteration 164 at date 200509, lookback period is 200409 to 200508 (12 months)
# Iteration 165 at date 200510, lookback period is 200410 to 200509 (12 months)
# Iteration 166 at date 200511, lookback period is 200411 to 200510 (12 months)
# Iteration 167 at date 200512, lookback period is 200412 to 200511 (12 months)
# Iteration 168 at date 200601, lookback period is 200501 to 200512 (12 months)
# Iteration 169 at date 200602, lookback period is 200502 to 200601 (12 months)
# Iteration 170 at date 200603, lookback period is 200503 to 200602 (12 months)
# Iteration 171 at date 200604, lookback period is 200504 to 200603 (12 months)
# Iteration 172 at date 200605, lookback period is 200505 to 200604 (12 months)
# Iteration 173 at date 200606, lookback period is 200506 to 200605 (12 months)
# Iteration 174 at date 200607, lookback period is 200507 to 200606 (12 months)
# Iteration 175 at date 200608, lookback period is 200508 to 200607 (12 months)
# Iteration 176 at date 200609, lookback period is 200509 to 200608 (12 months)
# Iteration 177 at date 200610, lookback period is 200510 to 200609 (12 months)
# Iteration 178 at date 200611, lookback period is 200511 to 200610 (12 months)
# Iteration 179 at date 200612, lookback period is 200512 to 200611 (12 months)
# Iteration 180 at date 200701, lookback period is 200601 to 200612 (12 months)
# Iteration 181 at date 200702, lookback period is 200602 to 200701 (12 months)
# Iteration 182 at date 200703, lookback period is 200603 to 200702 (12 months)
# Iteration 183 at date 200704, lookback period is 200604 to 200703 (12 months)
# Iteration 184 at date 200705, lookback period is 200605 to 200704 (12 months)
# Iteration 185 at date 200706, lookback period is 200606 to 200705 (12 months)
# Iteration 186 at date 200707, lookback period is 200607 to 200706 (12 months)
# Iteration 187 at date 200708, lookback period is 200608 to 200707 (12 months)
# Iteration 188 at date 200709, lookback period is 200609 to 200708 (12 months)
# Iteration 189 at date 200710, lookback period is 200610 to 200709 (12 months)
# Iteration 190 at date 200711, lookback period is 200611 to 200710 (12 months)
# Iteration 191 at date 200712, lookback period is 200612 to 200711 (12 months)
# Iteration 192 at date 200801, lookback period is 200701 to 200712 (12 months)
# Iteration 193 at date 200802, lookback period is 200702 to 200801 (12 months)
# Iteration 194 at date 200803, lookback period is 200703 to 200802 (12 months)
# Iteration 195 at date 200804, lookback period is 200704 to 200803 (12 months)
# Iteration 196 at date 200805, lookback period is 200705 to 200804 (12 months)
# Iteration 197 at date 200806, lookback period is 200706 to 200805 (12 months)
# Iteration 198 at date 200807, lookback period is 200707 to 200806 (12 months)
# Iteration 199 at date 200808, lookback period is 200708 to 200807 (12 months)
# Iteration 200 at date 200809, lookback period is 200709 to 200808 (12 months)
# Iteration 201 at date 200810, lookback period is 200710 to 200809 (12 months)
# Iteration 202 at date 200811, lookback period is 200711 to 200810 (12 months)
# Iteration 203 at date 200812, lookback period is 200712 to 200811 (12 months)
# Iteration 204 at date 200901, lookback period is 200801 to 200812 (12 months)
# Iteration 205 at date 200902, lookback period is 200802 to 200901 (12 months)
# Iteration 206 at date 200903, lookback period is 200803 to 200902 (12 months)
# Iteration 207 at date 200904, lookback period is 200804 to 200903 (12 months)
# Iteration 208 at date 200905, lookback period is 200805 to 200904 (12 months)
# Iteration 209 at date 200906, lookback period is 200806 to 200905 (12 months)
# Iteration 210 at date 200907, lookback period is 200807 to 200906 (12 months)
# Iteration 211 at date 200908, lookback period is 200808 to 200907 (12 months)
# Iteration 212 at date 200909, lookback period is 200809 to 200908 (12 months)
# Iteration 213 at date 200910, lookback period is 200810 to 200909 (12 months)
# Iteration 214 at date 200911, lookback period is 200811 to 200910 (12 months)
# Iteration 215 at date 200912, lookback period is 200812 to 200911 (12 months)
# Iteration 216 at date 201001, lookback period is 200901 to 200912 (12 months)
# Iteration 217 at date 201002, lookback period is 200902 to 201001 (12 months)
# Iteration 218 at date 201003, lookback period is 200903 to 201002 (12 months)
# Iteration 219 at date 201004, lookback period is 200904 to 201003 (12 months)
# Iteration 220 at date 201005, lookback period is 200905 to 201004 (12 months)
# Iteration 221 at date 201006, lookback period is 200906 to 201005 (12 months)
# Iteration 222 at date 201007, lookback period is 200907 to 201006 (12 months)
# Iteration 223 at date 201008, lookback period is 200908 to 201007 (12 months)
# Iteration 224 at date 201009, lookback period is 200909 to 201008 (12 months)
# Iteration 225 at date 201010, lookback period is 200910 to 201009 (12 months)
# Iteration 226 at date 201011, lookback period is 200911 to 201010 (12 months)
# Iteration 227 at date 201012, lookback period is 200912 to 201011 (12 months)
# Iteration 228 at date 201101, lookback period is 201001 to 201012 (12 months)
# Iteration 229 at date 201102, lookback period is 201002 to 201101 (12 months)
# Iteration 230 at date 201103, lookback period is 201003 to 201102 (12 months)
# Iteration 231 at date 201104, lookback period is 201004 to 201103 (12 months)
# Iteration 232 at date 201105, lookback period is 201005 to 201104 (12 months)
# Iteration 233 at date 201106, lookback period is 201006 to 201105 (12 months)
# Iteration 234 at date 201107, lookback period is 201007 to 201106 (12 months)
# Iteration 235 at date 201108, lookback period is 201008 to 201107 (12 months)
# Iteration 236 at date 201109, lookback period is 201009 to 201108 (12 months)
# Iteration 237 at date 201110, lookback period is 201010 to 201109 (12 months)
# Iteration 238 at date 201111, lookback period is 201011 to 201110 (12 months)
# Iteration 239 at date 201112, lookback period is 201012 to 201111 (12 months)
# Iteration 240 at date 201201, lookback period is 201101 to 201112 (12 months)
# Iteration 241 at date 201202, lookback period is 201102 to 201201 (12 months)
# Iteration 242 at date 201203, lookback period is 201103 to 201202 (12 months)
# Iteration 243 at date 201204, lookback period is 201104 to 201203 (12 months)
# Iteration 244 at date 201205, lookback period is 201105 to 201204 (12 months)
# Iteration 245 at date 201206, lookback period is 201106 to 201205 (12 months)
# Iteration 246 at date 201207, lookback period is 201107 to 201206 (12 months)
# Iteration 247 at date 201208, lookback period is 201108 to 201207 (12 months)
# Iteration 248 at date 201209, lookback period is 201109 to 201208 (12 months)
# Iteration 249 at date 201210, lookback period is 201110 to 201209 (12 months)
# Iteration 250 at date 201211, lookback period is 201111 to 201210 (12 months)
# Iteration 251 at date 201212, lookback period is 201112 to 201211 (12 months)
# Iteration 252 at date 201301, lookback period is 201201 to 201212 (12 months)
# Iteration 253 at date 201302, lookback period is 201202 to 201301 (12 months)
# Iteration 254 at date 201303, lookback period is 201203 to 201302 (12 months)
# Iteration 255 at date 201304, lookback period is 201204 to 201303 (12 months)
# Iteration 256 at date 201305, lookback period is 201205 to 201304 (12 months)
# Iteration 257 at date 201306, lookback period is 201206 to 201305 (12 months)
# Iteration 258 at date 201307, lookback period is 201207 to 201306 (12 months)
# Iteration 259 at date 201308, lookback period is 201208 to 201307 (12 months)
# Iteration 260 at date 201309, lookback period is 201209 to 201308 (12 months)
# Iteration 261 at date 201310, lookback period is 201210 to 201309 (12 months)
# Iteration 262 at date 201311, lookback period is 201211 to 201310 (12 months)
# Iteration 263 at date 201312, lookback period is 201212 to 201311 (12 months)
# Iteration 264 at date 201401, lookback period is 201301 to 201312 (12 months)
# Iteration 265 at date 201402, lookback period is 201302 to 201401 (12 months)
# Iteration 266 at date 201403, lookback period is 201303 to 201402 (12 months)
# Iteration 267 at date 201404, lookback period is 201304 to 201403 (12 months)
# Iteration 268 at date 201405, lookback period is 201305 to 201404 (12 months)
# Iteration 269 at date 201406, lookback period is 201306 to 201405 (12 months)
# Iteration 270 at date 201407, lookback period is 201307 to 201406 (12 months)
# Iteration 271 at date 201408, lookback period is 201308 to 201407 (12 months)
# Iteration 272 at date 201409, lookback period is 201309 to 201408 (12 months)
# Iteration 273 at date 201410, lookback period is 201310 to 201409 (12 months)
# Iteration 274 at date 201411, lookback period is 201311 to 201410 (12 months)
# Iteration 275 at date 201412, lookback period is 201312 to 201411 (12 months)
# Iteration 276 at date 201501, lookback period is 201401 to 201412 (12 months)
# Iteration 277 at date 201502, lookback period is 201402 to 201501 (12 months)
# Iteration 278 at date 201503, lookback period is 201403 to 201502 (12 months)
# Iteration 279 at date 201504, lookback period is 201404 to 201503 (12 months)
# Iteration 280 at date 201505, lookback period is 201405 to 201504 (12 months)
# Iteration 281 at date 201506, lookback period is 201406 to 201505 (12 months)
# Iteration 282 at date 201507, lookback period is 201407 to 201506 (12 months)
# Iteration 283 at date 201508, lookback period is 201408 to 201507 (12 months)
# Iteration 284 at date 201509, lookback period is 201409 to 201508 (12 months)
# Iteration 285 at date 201510, lookback period is 201410 to 201509 (12 months)
# Iteration 286 at date 201511, lookback period is 201411 to 201510 (12 months)
# Iteration 287 at date 201512, lookback period is 201412 to 201511 (12 months)
# Iteration 288 at date 201601, lookback period is 201501 to 201512 (12 months)
# Iteration 289 at date 201602, lookback period is 201502 to 201601 (12 months)
# Iteration 290 at date 201603, lookback period is 201503 to 201602 (12 months)
# Iteration 291 at date 201604, lookback period is 201504 to 201603 (12 months)
# Iteration 292 at date 201605, lookback period is 201505 to 201604 (12 months)
# Iteration 293 at date 201606, lookback period is 201506 to 201605 (12 months)
# Iteration 294 at date 201607, lookback period is 201507 to 201606 (12 months)
# Iteration 295 at date 201608, lookback period is 201508 to 201607 (12 months)
# Iteration 296 at date 201609, lookback period is 201509 to 201608 (12 months)
# Iteration 297 at date 201610, lookback period is 201510 to 201609 (12 months)
# Iteration 298 at date 201611, lookback period is 201511 to 201610 (12 months)
# Iteration 299 at date 201612, lookback period is 201512 to 201611 (12 months)
# Iteration 300 at date 201701, lookback period is 201601 to 201612 (12 months)
# Iteration 301 at date 201702, lookback period is 201602 to 201701 (12 months)
# Iteration 302 at date 201703, lookback period is 201603 to 201702 (12 months)
# Iteration 303 at date 201704, lookback period is 201604 to 201703 (12 months)
# Iteration 304 at date 201705, lookback period is 201605 to 201704 (12 months)
# Iteration 305 at date 201706, lookback period is 201606 to 201705 (12 months)
# Iteration 306 at date 201707, lookback period is 201607 to 201706 (12 months)
# Iteration 307 at date 201708, lookback period is 201608 to 201707 (12 months)
# Iteration 308 at date 201709, lookback period is 201609 to 201708 (12 months)
# Iteration 309 at date 201710, lookback period is 201610 to 201709 (12 months)
# Iteration 310 at date 201711, lookback period is 201611 to 201710 (12 months)
# Iteration 311 at date 201712, lookback period is 201612 to 201711 (12 months)
# Iteration 312 at date 201801, lookback period is 201701 to 201712 (12 months)
# Iteration 313 at date 201802, lookback period is 201702 to 201801 (12 months)
# Iteration 314 at date 201803, lookback period is 201703 to 201802 (12 months)
# Iteration 315 at date 201804, lookback period is 201704 to 201803 (12 months)
# Iteration 316 at date 201805, lookback period is 201705 to 201804 (12 months)
# Iteration 317 at date 201806, lookback period is 201706 to 201805 (12 months)
# Iteration 318 at date 201807, lookback period is 201707 to 201806 (12 months)
# Iteration 319 at date 201808, lookback period is 201708 to 201807 (12 months)
# Iteration 320 at date 201809, lookback period is 201709 to 201808 (12 months)
# Iteration 321 at date 201810, lookback period is 201710 to 201809 (12 months)
# Iteration 322 at date 201811, lookback period is 201711 to 201810 (12 months)
# Iteration 323 at date 201812, lookback period is 201712 to 201811 (12 months)
# Iteration 324 at date 201901, lookback period is 201801 to 201812 (12 months)
# Iteration 325 at date 201902, lookback period is 201802 to 201901 (12 months)
# Iteration 326 at date 201903, lookback period is 201803 to 201902 (12 months)
# Iteration 327 at date 201904, lookback period is 201804 to 201903 (12 months)
# Iteration 328 at date 201905, lookback period is 201805 to 201904 (12 months)
# Iteration 329 at date 201906, lookback period is 201806 to 201905 (12 months)
# Iteration 330 at date 201907, lookback period is 201807 to 201906 (12 months)
# Iteration 331 at date 201908, lookback period is 201808 to 201907 (12 months)
# Iteration 332 at date 201909, lookback period is 201809 to 201908 (12 months)
# Iteration 333 at date 201910, lookback period is 201810 to 201909 (12 months)
# Iteration 334 at date 201911, lookback period is 201811 to 201910 (12 months)
# Iteration 335 at date 201912, lookback period is 201812 to 201911 (12 months)
# Iteration 336 at date 202001, lookback period is 201901 to 201912 (12 months)
# Iteration 337 at date 202002, lookback period is 201902 to 202001 (12 months)
# Iteration 338 at date 202003, lookback period is 201903 to 202002 (12 months)
# Iteration 339 at date 202004, lookback period is 201904 to 202003 (12 months)
# Iteration 340 at date 202005, lookback period is 201905 to 202004 (12 months)
# Iteration 341 at date 202006, lookback period is 201906 to 202005 (12 months)
# Iteration 342 at date 202007, lookback period is 201907 to 202006 (12 months)
# Iteration 343 at date 202008, lookback period is 201908 to 202007 (12 months)
# Iteration 344 at date 202009, lookback period is 201909 to 202008 (12 months)
# Iteration 345 at date 202010, lookback period is 201910 to 202009 (12 months)
# Iteration 346 at date 202011, lookback period is 201911 to 202010 (12 months)
# Iteration 347 at date 202012, lookback period is 201912 to 202011 (12 months)
#
# Done.

# %% [markdown]
# ## Print the first 10.000 rows to Excel for manual inspection

# %%
# Print the first 10.000 rows to Excel for inspection:
#data.head(10000).to_excel('Fund data with new attributes - inspection.xlsx')

# %% [markdown]
# # Creating a strategy based on mutual funds ("rank portfolios")
# ### The idea is simple: once a year we select the mutual funds with the highest return over the previous year. We then buy those mutual funds (equally-weighted) and hold onto them for a year. We then "rebalance" by repeating the procedure (selecting the new best funds), hold onto them for a year, etc.

# %%
# Settings
lookforward = 12                # Evaluation period is 12 (or 3 or 1) months (one year into the future). 
rebalance = lookforward         # Rebalancing frequency is equal to lookforward period (every 12 months)
number_quantiles = 10           # Number of quantile portfolios to create. For this example we will create DECILES.
#rank_variable = '12M return'    # Characteristic on which funds will be sorted into quantiles
rank_variable = 'mgmt_fee'    # Characteristic on which funds will be sorted into quantiles

# Get the string representation of the months starting in December 1992 (first rebalancing moment)
dates = famafrench.index[famafrench.index >= 199212].unique()

# Initialize results
quantile_portfolios = pd.DataFrame(data=None, index=dates, columns=range(0, number_quantiles))
quantile_portfolios_other_variable_pd = pd.DataFrame(data=None, index=dates, columns=range(0, number_quantiles))

# Loop over the dates
for period in trange(0, len(dates), rebalance):
    
    #print(f'the period is {period}')

    # Get the current date
    current_date = dates[period]
    #print(f'the current date is {current_date}')
    
    # Get all dates of the next year (lookforward window)
    lookforward_period = dates[period+1:period+lookforward+1]
    #print(f'the lookforward period is {lookforward_period}')
    
    # Assign a cumulative number for each period in the future (so we can group by this later)
    quantile_portfolios_index = quantile_portfolios.index.isin(lookforward_period)
    quantile_portfolios.loc[quantile_portfolios_index, 'Holding period'] = range(1, len(lookforward_period)+1)
    
    # Get all funds at this period in time (in this iteration)
    funds_this_period_index = data.index.get_level_values('YYYYMM') == current_date
    funds_this_period = data.loc[funds_this_period_index]
    
    # If less than 100 funds in total, ignore the code below
    if funds_this_period[rank_variable].count() < 100:
        continue
    
    # Sort the funds into quantiles (using pandas 'qcut' function)
    quantiles_index = pd.qcut(funds_this_period[rank_variable], number_quantiles, labels=range(0, number_quantiles))
    
    # Loop over each quantile
    for q in range(0, number_quantiles):
        
        # Get the fund identifiers that are part of this quantile
        funds_in_quantile = quantiles_index.index.get_level_values('crsp_fundno')[quantiles_index == q]
        
        # Get the forward-looking returns of the funds that belong to this quantile
        fund_returns_index = np.logical_and(
            data.index.get_level_values('YYYYMM').isin(lookforward_period),
            data.index.get_level_values('crsp_fundno').isin(funds_in_quantile)
        )
        fund_returns = data.loc[fund_returns_index, 'mret']
        fund_other_rank_variable = data.loc[fund_returns_index, rank_variable]
        
        # Put the dates as columns (instead of having a multi-column index, make separate columns for each date)
        fund_returns = fund_returns.unstack(level='YYYYMM')
        fund_other_rank_variable = fund_other_rank_variable.unstack(level='YYYYMM')
        
        # Define the weighting scheme.
        # For now, we will created equally-weighted quantile portfolios.
        # We assume that if a mutual fund closes, we can reinvest our redeemed money in the remaining funds.
        # These weights are the basis for the other rank variable 
        fund_weights = fund_returns.notna().astype(int)
        fund_weights = fund_weights.div(fund_weights.sum(axis=0), axis=1)
        
        # Multiply returns with weights to get the return of the quantile portfolio and also for the other variable
        quantile_portfolio_return = (fund_returns * fund_weights).sum(axis=0, skipna=True)
        quantile_portfolios_other_variable = (fund_other_rank_variable * fund_weights).sum(axis=0, skipna=True)
        
        # Save the future returns for this quantile in the 'quantile_portfolios' dataframe
        quantile_portfolios_index = quantile_portfolios.index.isin(lookforward_period)
        quantile_portfolios.loc[quantile_portfolios_index, q] = quantile_portfolio_return
        quantile_portfolios_other_variable_index = quantile_portfolios_other_variable_pd.index.isin(lookforward_period)
        quantile_portfolios_other_variable_pd.loc[quantile_portfolios_other_variable_index, q] = quantile_portfolios_other_variable        
        
print('Quantile portfolios are created.')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=29.0), HTML(value='')))
# Quantile portfolios are created.

# %% [markdown]
# ### This is for creating a lag of 1 month. Run only if necessary

# %%
# # Settings
# lag = 1                         # lag of 1 month
# lookforward = 12                # Evaluation period is 12 (or 3 or 1) months (one year into the future). 
# rebalance = lookforward + lag   # Rebalancing frequency is NOT equal to lookforward period (every 13 months)
# number_quantiles = 10           # Number of quantile portfolios to create. For this example we will create DECILES.
# #rank_variable = '12M return'   # Characteristic on which funds will be sorted into quantiles
# rank_variable = 'mgmt_fee'      # Characteristic on which funds will be sorted into quantiles

# # Get the string representation of the months starting in December 1992 (first rebalancing moment)
# dates = famafrench.index[famafrench.index >= 199212].unique()

# # Initialize results
# quantile_portfolios = pd.DataFrame(data=None, index=dates, columns=range(0, number_quantiles))
# quantile_portfolios_other_variable_pd = pd.DataFrame(data=None, index=dates, columns=range(0, number_quantiles))

# # Loop over the dates
# for period in trange(0, len(dates), rebalance):
    
#     #print(f'the period is {period}')

#     # Get the current date
#     current_date = dates[period]
#     #print(f'the current date is {current_date}')
    
#     # Get all dates of the next year (lookforward window)
#     lookforward_period = dates[period+1:period+lookforward+1]
#     #print(f'the lookforward period is {lookforward_period}')
    
#     # Assign a cumulative number for each period in the future (so we can group by this later)
#     quantile_portfolios_index = quantile_portfolios.index.isin(lookforward_period)
#     quantile_portfolios.loc[quantile_portfolios_index, 'Holding period'] = range(1, len(lookforward_period)+1)
    
#     # Get all funds at this period in time (in this iteration)
#     funds_this_period_index = data.index.get_level_values('YYYYMM') == current_date
#     funds_this_period = data.loc[funds_this_period_index]
    
#     # If less than 100 funds in total, ignore the code below
#     if funds_this_period[rank_variable].count() < 100:
#         continue
    
#     # Sort the funds into quantiles (using pandas 'qcut' function)
#     quantiles_index = pd.qcut(funds_this_period[rank_variable], number_quantiles, labels=range(0, number_quantiles))
    
#     # Loop over each quantile
#     for q in range(0, number_quantiles):
        
#         # Get the fund identifiers that are part of this quantile
#         funds_in_quantile = quantiles_index.index.get_level_values('crsp_fundno')[quantiles_index == q]
        
#         # Get the forward-looking returns of the funds that belong to this quantile
#         fund_returns_index = np.logical_and(
#             data.index.get_level_values('YYYYMM').isin(lookforward_period),
#             data.index.get_level_values('crsp_fundno').isin(funds_in_quantile)
#         )
#         fund_returns = data.loc[fund_returns_index, 'mret']
#         fund_other_rank_variable = data.loc[fund_returns_index, rank_variable]
        
#         # Put the dates as columns (instead of having a multi-column index, make separate columns for each date)
#         fund_returns = fund_returns.unstack(level='YYYYMM')
#         fund_other_rank_variable = fund_other_rank_variable.unstack(level='YYYYMM')
        
#         # Define the weighting scheme.
#         # For now, we will created equally-weighted quantile portfolios.
#         # We assume that if a mutual fund closes, we can reinvest our redeemed money in the remaining funds.
#         # These weights are the basis for the other rank variable 
#         fund_weights = fund_returns.notna().astype(int)
#         fund_weights = fund_weights.div(fund_weights.sum(axis=0), axis=1)
        
#         # Multiply returns with weights to get the return of the quantile portfolio and also for the other variable
#         quantile_portfolio_return = (fund_returns * fund_weights).sum(axis=0, skipna=True)
#         quantile_portfolios_other_variable = (fund_other_rank_variable * fund_weights).sum(axis=0, skipna=True)
        
#         # Save the future returns for this quantile in the 'quantile_portfolios' dataframe
#         quantile_portfolios_index = quantile_portfolios.index.isin(lookforward_period)
#         quantile_portfolios.loc[quantile_portfolios_index, q] = quantile_portfolio_return
#         quantile_portfolios_other_variable_index = quantile_portfolios_pd.index.isin(lookforward_period)
#         quantile_portfolios_other_variable_pd.loc[quantile_portfolios_other_variable_index, q] = quantile_portfolios_other_variable        
        
# print('Quantile portfolios are created.')

# %% [markdown]
# ### Plot cumulative returns of quantile portfolios

# %%
# # Calculate cumulative log returns of quantile portfolios
# quantile_portfolios_cumprod = np.cumprod(1 + quantile_portfolios, axis=0) - 1

# # Add Python datetime to the dataframe (new column called "Date")
# quantile_portfolios_cumprod['Date'] = pd.to_datetime(quantile_portfolios_cumprod.index, format="%Y%m")

# # Plot the cumulative fama-french factors over time
# figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
# plt.plot(quantile_portfolios_cumprod['Date'], quantile_portfolios_cumprod[range(0,number_quantiles)])
# plt.title('Cumulative returns over time')
# plt.legend(["Quantile {}".format(q) for q in range(1,number_quantiles+1)])
# plt.xlabel('Time (months)')
# plt.ylabel('Cumulative arithmetic returns')
# plt.show()

# %% [markdown]
# ### Plot holding-period return for each quantile
# _Edit: this plot now works for any holding period_

# %%
# # Get the string representation of the months starting in December 1992 (first rebalancing moment)
# dates = famafrench.index[famafrench.index >= 199212].unique()

# # Because portfolios are rebalanced every December, we can simply keep track of the return in each month
# portfolio_returns = quantile_portfolios.copy()

# # Calculate the average returns per portfolio, per month
# returns_per_month = portfolio_returns.fillna(0).groupby(['Holding period']).mean()

# # Calculate the holding-period cumulative return
# holding_returns = np.cumprod(1 + returns_per_month, axis=0) - 1

# # Add a column with the average return per holding period
# holding_returns['Average'] = holding_returns.mean(axis=1)

# # For each fund, subtract the average return
# for q in range(0,number_quantiles):
#     holding_returns[q] = holding_returns[q] - holding_returns['Average']
    
# # Plot the cumulative fama-french factors over time
# figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
# plt.plot(holding_returns.index, holding_returns[range(0, number_quantiles)])
# plt.title('Cumulative returns over holding period')
# plt.legend(["Q{}".format(q) for q in range(1, number_quantiles+1)], loc='lower left')
# plt.xlabel('Holding period (months)')
# plt.ylabel('Cumulative returns in excess of the average')
# plt.show()

# %% [markdown]
# ### Quantile portfolio statistics - Multi Factor

# %%
# Multi-factor
factor_model = 'Multi-Factor' 

# Specify portfolios to analyze
portfolios = quantile_portfolios

# Load Fama-French factors
ff = famafrench[famafrench.index.isin(portfolios.index)]

# Merge together
portfolios = portfolios.merge(ff, left_index=True, right_index=True, how='left')

# Initialize results
cols = ["Management fees", "Avg returns", "Avg excess returns", "Volatility", "Sharpe ratio", 
        "Alpha", "Std. error (α)", "t-stat (α)", "p-value (α)", "Beta",
        "SMB", "HML", "WML", "RMW", 'CMA', "R2 adjusted"]
results = pd.DataFrame(data=None, index=portfolios.columns, columns=cols)

# Calculate management fees
results["Management fees"] = quantile_portfolios_other_variable_pd.mean() * 12

# Calculate average returns
results["Avg returns"] = portfolios.mean() * 12
results.loc[:, "Avg excess returns"] = results.loc[:, "Avg returns"] - results.loc["RF", "Avg returns"]

# Calculate volatility of returns
results["Volatility"] = portfolios.std() * np.sqrt(12)

# Calculate Sharpe ratio
results["Sharpe ratio"] = results["Avg excess returns"] / results["Volatility"]

# Loop over each portfolio
for quantile in range(0, number_quantiles):
    
    # Find index of available data
    index = portfolios[quantile].notna()
    
    # Get x and y variables
    x = portfolios.loc[index, ['Mkt-RF', 'SMB', 'HML', 'WML', 'RMW', 'CMA']].astype(float)
    y = portfolios.loc[index, quantile].astype(float) - portfolios.loc[index, 'RF']
    if quantile == 0:
        matrix_factor_returns = y[0:251]
    else:
        matrix_factor_returns = np.vstack((matrix_res,y[0:251]))
    
    # Note! Need to add intercept myself using this syntax
    x = sm.add_constant(x)
    
    # Fit regression
    model = sm.OLS(y, x).fit()   # Note! y and x are passed to this function in reverse order. It differs per package!
    
    # Save alpha
    results.loc[quantile, "Alpha"] = model.params[0] * 12
    
    # Save standard error of the alpha
    results.loc[quantile, "Std. error (α)"] = model.bse[0]
    
    # Save tstat of the alpha
    results.loc[quantile, "t-stat (α)"] = model.tvalues[0]
    
    # Save p-value of the alpha
    results.loc[quantile, "p-value (α)"] = model.pvalues[0]
    
    # Save beta
    results.loc[quantile, "Beta"] = model.params[1]
    
    # Save SMB
    results.loc[quantile, "SMB"] = model.params[2]
    
    # Save HML
    results.loc[quantile, "HML"] = model.params[3]
    
    # Save RF
    #results.loc[quantile, "RF"] = model.params[4]
    
    # Save WML
    results.loc[quantile, "WML"] = model.params[4]
    
     # Save RMW
    results.loc[quantile, "RMW"] = model.params[5]
    
     # Save CMA
    results.loc[quantile, "CMA"] = model.params[6]
    
    # Save R squared adjusted
    results.loc[quantile, "R2 adjusted"] = model.rsquared_adj
    
    # Save residuals
    vector_resid = model.resid.values[0:251]
    if quantile == 0:
        matrix_res = vector_resid
    else:
        matrix_res = np.vstack((matrix_res,vector_resid))
    
# Only keep results for relevant factors
results = results.loc[range(0, number_quantiles)]
results.index = ["Q{}".format(q) for q in range(1, number_quantiles+1)]

# Print final results
print(f'Based on {factor_model} model, \n\
{lookback} month formation period and {lookforward} month holding period,')
if lookforward != rebalance:
    print(f'with a lag of {rebalance-lookforward} month,')
print('the final results are (all numbers annualized):')
display(results.T)
# Out:
# Based on Multi-Factor model,
# 12 month formation period and 12 month holding period,
# the final results are (all numbers annualized):
#                              Q1           Q2           Q3           Q4  \
# Management fees        0.858648      2.01374      3.25046      4.45188
# Avg returns           0.0780334    0.0866592    0.0744563    0.0742097
# Avg excess returns     0.054977    0.0636028    0.0513999    0.0511533
# Volatility              0.15501     0.155485     0.154041     0.156863
# Sharpe ratio           0.354668     0.409062     0.333677     0.326101
# Alpha               -0.00379367   0.00164921  -0.00169634  -0.00327665
# Std. error (α)      0.000295111  0.000644409  0.000531274  0.000454916
# t-stat (α)             -1.07125     0.213271     -0.26608    -0.600231
# p-value (α)            0.285114     0.831293     0.790401     0.548907
# Beta                   0.988826     0.967158     0.951315      0.95383
# SMB                  -0.0278356    0.0736993    0.0138792     0.062875
# HML                   0.0411528    0.0826416    0.0347181    0.0557997
# WML                  -0.0302202   0.00235403    0.0208733   0.00946903
# RMW                   0.0776501    0.0796176   -0.0447392   -0.0597156
# CMA                   0.0218005    0.0214248     -0.04348   -0.0364201
# R2 adjusted            0.990342     0.954177      0.96825     0.977546
#
#                              Q5           Q6           Q7           Q8  \
# Management fees         5.64816      6.61188      7.33924       8.1159
# Avg returns           0.0628151    0.0727015    0.0721068    0.0877381
# Avg excess returns    0.0397587    0.0496451    0.0490504    0.0646817
# Volatility             0.164117      0.15302     0.156597     0.168363
# Sharpe ratio           0.242258     0.324436     0.313228     0.384179
# Alpha               -0.00870896  -0.00467677   0.00191471    0.0101277
# Std. error (α)      0.000434431  0.000634062  0.000523942  0.000857149
# t-stat (α)             -1.67057    -0.614657     0.304536     0.984633
# p-value (α)            0.096084     0.539352     0.760978     0.325776
# Beta                   0.969162     0.931178     0.930739     0.997874
# SMB                   0.0259187    0.0648084    0.0329454    0.0327872
# HML                  0.00494842    0.0215439  -0.00319398   -0.0350498
# WML                  -0.0176629    0.0222458   0.00457798    0.0220736
# RMW                    -0.14046   -0.0306899    -0.105346    -0.123624
# CMA                  -0.0693213   -0.0355654     -0.10607    0.0233118
# R2 adjusted            0.981282     0.954106     0.970115     0.930571
#
#                              Q9          Q10
# Management fees         9.37922      11.8717
# Avg returns            0.071618    0.0653447
# Avg excess returns    0.0485617    0.0422883
# Volatility              0.16926      0.16773
# Sharpe ratio           0.286906     0.252121
# Alpha               -0.00759291  -0.00843069
# Std. error (α)      0.000516987  0.000667786
# t-stat (α)              -1.2239     -1.05207
# p-value (α)            0.222165     0.293804
# Beta                    1.00016     0.915814
# SMB                    0.118586     0.266145
# HML                   0.0197602   -0.0211823
# WML                  0.00777696    0.0571193
# RMW                  -0.0924251    -0.179961
# CMA                  -0.0851427    -0.146058
# R2 adjusted            0.975078     0.957647

# %%
matrix_y
# Out:
# array([[ 0.00237126, -0.00861378,  0.01179809, ...,  0.0046263 ,
#          0.00224411, -0.00207681],
#        [ 0.01117314,  0.00373347,  0.00759908, ...,  0.00364815,
#         -0.00632699, -0.00951852],
#        [ 0.00602508,  0.02086251,  0.00554359, ...,  0.02412807,
#          0.01177576, -0.06826424],
#        ...,
#        [-0.00124853,  0.02358279, -0.00056648, ...,  0.00377886,
#          0.00843241, -0.00211683],
#        [ 0.00255942,  0.02349367,  0.01417387, ...,  0.00859823,
#          0.00203879, -0.02225672],
#        [-0.02832206,  0.16821239, -0.00746182, ..., -0.03531658,
#         -0.00504587,  0.13025721]])

# %% [markdown]
# ### Quantile portfolio statistics - Fama French 5 factor

# %%
# Fama French 5 factor
factor_model = 'Fama-French 5 factor'

# Specify portfolios to analyze
portfolios = quantile_portfolios

# Load Fama-French factors
ff = famafrench[famafrench.index.isin(portfolios.index)]

# Merge together
portfolios = portfolios.merge(ff, left_index=True, right_index=True, how='left')

# Initialize results
cols = ["Avg returns", "Avg excess returns", "Volatility", "Sharpe ratio", 
        "Alpha", "Std. error (α)", "t-stat (α)", "p-value (α)", "Beta",
        "SMB", "HML", "RMW", 'CMA', "R2 adjusted"]
results = pd.DataFrame(data=None, index=portfolios.columns, columns=cols)

# Calculate average returns
results["Avg returns"] = portfolios.mean() * 12
results.loc[:, "Avg excess returns"] = results.loc[:, "Avg returns"] - results.loc["RF", "Avg returns"]

# Calculate volatility of returns
results["Volatility"] = portfolios.std() * np.sqrt(12)

# Calculate Sharpe ratio
results["Sharpe ratio"] = results["Avg excess returns"] / results["Volatility"]

# Initialize matrix of model residuals and factor returns
matrix_res = []
matrix_y = []

# Loop over each portfolio
for quantile in range(0, number_quantiles):
    
    # Find index of available data
    index = portfolios[quantile].notna()
    
    # Get x and y variables
    x = portfolios.loc[index, ['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA']].astype(float)
    y = portfolios.loc[index, quantile].astype(float) - portfolios.loc[index, 'RF']
    matrix_y.append(y.values)
    matrix_y_t = np.transpose(np.array(matrix_y))
    
    # Note! Need to add intercept myself using this syntax
    x = sm.add_constant(x)
    
    # Fit regression
    model = sm.OLS(y, x).fit()   # Note! y and x are passed to this function in reverse order. It differs per package!
    
    # Save alpha
    results.loc[quantile, "Alpha"] = model.params[0] * 12
    
    # Save standard error of the alpha
    results.loc[quantile, "Std. error (α)"] = model.bse[0]
    
    # Save tstat of the alpha
    results.loc[quantile, "t-stat (α)"] = model.tvalues[0]
    
    # Save p-value of the alpha
    results.loc[quantile, "p-value (α)"] = model.pvalues[0]
    
    # Save beta
    results.loc[quantile, "Beta"] = model.params[1]
    
    # Save SMB
    results.loc[quantile, "SMB"] = model.params[2]
    
    # Save HML
    results.loc[quantile, "HML"] = model.params[3]
    
    # Save RF
    #results.loc[quantile, "RF"] = model.params[4]
    
     # Save RMW
    results.loc[quantile, "RMW"] = model.params[4]
    
     # Save CMA
    results.loc[quantile, "CMA"] = model.params[5]
    
    # Save R squared adjusted
    results.loc[quantile, "R2 adjusted"] = model.rsquared_adj
    
    # Save residuals
    matrix_res.append(model.resid.values)
    matrix_res_t = np.transpose(np.array(matrix_res))
    
    
# Only keep results for relevant factors
results = results.loc[range(0, number_quantiles)]
results.index = ["Q{}".format(q) for q in range(1, number_quantiles+1)]

# Print final results
print(f'Based on {factor_model} model, \n\
{lookback} month formation period and {lookforward} month holding period,')
if lookforward != rebalance:
    print(f'with a lag of {rebalance-lookforward} month,')
print('the final results are (all numbers annualized):')
display(results.T)

# %% [markdown]
# ### Quantile portfolio statistics - Carhart 4 factor

# %%
# Carhart
factor_model = 'Carthart 4-factor'

# Specify portfolios to analyze
portfolios = quantile_portfolios

# Load Fama-French factors
ff = famafrench[famafrench.index.isin(portfolios.index)]

# Merge together
portfolios = portfolios.merge(ff, left_index=True, right_index=True, how='left')

# Initialize results
cols = ["Avg returns", "Avg excess returns", "Volatility", "Sharpe ratio", 
        "Alpha", "Std. error (α)", "t-stat (α)", "p-value (α)", "Beta",
        "SMB", "HML", "WML", "R2 adjusted"]
results = pd.DataFrame(data=None, index=portfolios.columns, columns=cols)

# Calculate average returns
results["Avg returns"] = portfolios.mean() * 12
results.loc[:, "Avg excess returns"] = results.loc[:, "Avg returns"] - results.loc["RF", "Avg returns"]

# Calculate volatility of returns
results["Volatility"] = portfolios.std() * np.sqrt(12)

# Calculate Sharpe ratio
results["Sharpe ratio"] = results["Avg excess returns"] / results["Volatility"]

# Initialize matrix of model residuals and factor returns
matrix_res = []
matrix_y = []

# Loop over each portfolio
for quantile in range(0, number_quantiles):
    
    # Find index of available data
    index = portfolios[quantile].notna()
    
    # Get x and y variables
    x = portfolios.loc[index, ['Mkt-RF', 'SMB', 'HML', 'WML']].astype(float)
    y = portfolios.loc[index, quantile].astype(float) - portfolios.loc[index, 'RF']
    matrix_y.append(y.values)
    matrix_y_t = np.transpose(np.array(matrix_y))
    
    # Note! Need to add intercept myself using this syntax
    x = sm.add_constant(x)
    
    # Fit regression
    model = sm.OLS(y, x).fit()   # Note! y and x are passed to this function in reverse order. It differs per package!
    
    # Save alpha
    results.loc[quantile, "Alpha"] = model.params[0] * 12
    
    # Save standard error of the alpha
    results.loc[quantile, "Std. error (α)"] = model.bse[0]
    
    # Save tstat of the alpha
    results.loc[quantile, "t-stat (α)"] = model.tvalues[0]
    
    # Save p-value of the alpha
    results.loc[quantile, "p-value (α)"] = model.pvalues[0]
    
    # Save beta
    results.loc[quantile, "Beta"] = model.params[1]
    
    # Save SMB
    results.loc[quantile, "SMB"] = model.params[2]
    
    # Save HML
    results.loc[quantile, "HML"] = model.params[3]
    
    # Save RF
    #results.loc[quantile, "RF"] = model.params[4]
    
    # Save RML
    results.loc[quantile, "WML"] = model.params[4]
    
    # Save R squared adjusted
    results.loc[quantile, "R2 adjusted"] = model.rsquared_adj
    
    # Save residuals
    matrix_res.append(model.resid.values)
    matrix_res_t = np.transpose(np.array(matrix_res))
    
    
# Only keep results for relevant factors
results = results.loc[range(0, number_quantiles)]
results.index = ["Q{}".format(q) for q in range(1, number_quantiles+1)]

# Print final results
print(f'Based on {factor_model} model, \n\
{lookback} month formation period and {lookforward} month holding period,')
if lookforward != rebalance:
    print(f'with a lag of {rebalance-lookforward} month,')
print('the final results are (all numbers annualized):')
display(results.T)

# %% [markdown]
# ### Quantile portfolio statistics - Fama French 3 factor

# %%
# Fama French
factor_model = 'Fama-French 3 factor'

# Specify portfolios to analyze
portfolios = quantile_portfolios

# Load Fama-French factors
ff = famafrench[famafrench.index.isin(portfolios.index)]

# Merge together
portfolios = portfolios.merge(ff, left_index=True, right_index=True, how='left')

# Initialize results
cols = ["Avg returns", "Avg excess returns", "Volatility", "Sharpe ratio", 
        "Alpha", "Std. error (α)", "t-stat (α)", "p-value (α)", "Beta",
        "SMB", "HML"]#, "RF", "WML", "R2 adjusted"]
results = pd.DataFrame(data=None, index=portfolios.columns, columns=cols)

# Calculate average returns
results["Avg returns"] = portfolios.mean() * 12
results.loc[:, "Avg excess returns"] = results.loc[:, "Avg returns"] - results.loc["RF", "Avg returns"]

# Calculate volatility of returns
results["Volatility"] = portfolios.std() * np.sqrt(12)

# Calculate Sharpe ratio
results["Sharpe ratio"] = results["Avg excess returns"] / results["Volatility"]

# Initialize matrix of model residuals and factor returns
matrix_res = []
matrix_y = []

# Loop over each portfolio
for quantile in range(0, number_quantiles):
    
    # Find index of available data
    index = portfolios[quantile].notna()
    
    # Get x and y variables
    x = portfolios.loc[index, ['Mkt-RF', 'SMB', 'HML']].astype(float)
    y = portfolios.loc[index, quantile].astype(float) - portfolios.loc[index, 'RF']
    matrix_y.append(y.values)
    matrix_y_t = np.transpose(np.array(matrix_y))
    
    # Note! Need to add intercept myself using this syntax
    x = sm.add_constant(x)
    
    # Fit regression
    model = sm.OLS(y, x).fit()   # Note! y and x are passed to this function in reverse order. It differs per package!
    
    # Save alpha
    results.loc[quantile, "Alpha"] = model.params[0] * 12
    
    # Save standard error of the alpha
    results.loc[quantile, "Std. error (α)"] = model.bse[0]
    
    # Save tstat of the alpha
    results.loc[quantile, "t-stat (α)"] = model.tvalues[0]
    
    # Save p-value of the alpha
    results.loc[quantile, "p-value (α)"] = model.pvalues[0]
    
    # Save beta
    results.loc[quantile, "Beta"] = model.params[1]
    
    # Save SMB
    results.loc[quantile, "SMB"] = model.params[2]
    
    # Save HML
    results.loc[quantile, "HML"] = model.params[3]
    
    # Save RF
    #results.loc[quantile, "RF"] = model.params[4]
    
    # Save RML
    #results.loc[quantile, "WML"] = model.params[5]
    
    # Save R squared adjusted
    results.loc[quantile, "R2 adjusted"] = model.rsquared_adj
    
    # Save residuals
    matrix_res.append(model.resid.values)
    matrix_res_t = np.transpose(np.array(matrix_res))
    
    
# Only keep results for relevant factors
results = results.loc[range(0, number_quantiles)]
results.index = ["Q{}".format(q) for q in range(1, number_quantiles+1)]

# Print final results
print(f'Based on {factor_model} model, \n\
{lookback} month formation period and {lookforward} month holding period,')
if lookforward != rebalance:
    print(f'with a lag of {rebalance-lookforward} month,')
print('the final results are (all numbers annualized):')
display(results.T)

# %% [markdown]
# ### Quantile portfolio statistics - CAPM

# %%
# CAPM
factor_model = 'CAPM'

# Specify portfolios to analyze
portfolios = quantile_portfolios

# Load Fama-French factors
ff = famafrench[famafrench.index.isin(portfolios.index)]

# Merge together
portfolios = portfolios.merge(ff, left_index=True, right_index=True, how='left')

# Initialize results
cols = ["Avg returns", "Avg excess returns", "Volatility", "Sharpe ratio", 
        "Alpha", "Std. error (α)", "t-stat (α)", "p-value (α)", "Beta"]
        #"SMB", "HML", "RF", "WML", "R2 adjusted"]
results = pd.DataFrame(data=None, index=portfolios.columns, columns=cols)

# Calculate average returns
results["Avg returns"] = portfolios.mean() * 12
results.loc[:, "Avg excess returns"] = results.loc[:, "Avg returns"] - results.loc["RF", "Avg returns"]

# Calculate volatility of returns
results["Volatility"] = portfolios.std() * np.sqrt(12)

# Calculate Sharpe ratio
results["Sharpe ratio"] = results["Avg excess returns"] / results["Volatility"]

# Initialize matrix of model residuals and factor returns
matrix_res = []
matrix_y = []

# Loop over each portfolio
for quantile in range(0, number_quantiles):
    
    # Find index of available data
    index = portfolios[quantile].notna()
    
    # Get x and y variables
    x = portfolios.loc[index, ['Mkt-RF']].astype(float)
    y = portfolios.loc[index, quantile].astype(float) - portfolios.loc[index, 'RF']
    matrix_y.append(y.values)
    matrix_y_t = np.transpose(np.array(matrix_y))
    
    # Note! Need to add intercept myself using this syntax
    x = sm.add_constant(x)
    
    # Fit regression
    model = sm.OLS(y, x).fit()   # Note! y and x are passed to this function in reverse order. It differs per package!
    
    # Save alpha
    results.loc[quantile, "Alpha"] = model.params[0] * 12
    
    # Save standard error of the alpha
    results.loc[quantile, "Std. error (α)"] = model.bse[0]
    
    # Save tstat of the alpha
    results.loc[quantile, "t-stat (α)"] = model.tvalues[0]
    
    # Save p-value of the alpha
    results.loc[quantile, "p-value (α)"] = model.pvalues[0]
    
    # Save beta
    results.loc[quantile, "Beta"] = model.params[1]
    
    # Save SMB
    #results.loc[quantile, "SMB"] = model.params[2]
    
    # Save HML
    #results.loc[quantile, "HML"] = model.params[3]
    
    # Save RF
    #results.loc[quantile, "RF"] = model.params[4]
    
    # Save RML
    #results.loc[quantile, "WML"] = model.params[5]
    
    # Save R squared adjusted
    results.loc[quantile, "R2 adjusted"] = model.rsquared_adj
    
    # Save residuals
    matrix_res.append(model.resid.values)
    matrix_res_t = np.transpose(np.array(matrix_res))
    
    
# Only keep results for relevant factors
results = results.loc[range(0, number_quantiles)]
results.index = ["Q{}".format(q) for q in range(1, number_quantiles+1)]

# Print final results
print(f'Based on {factor_model} model, \n\
{lookback} month formation period and {lookforward} month holding period,')
if lookforward != rebalance:
    print(f'with a lag of {rebalance-lookforward} month,')
print('the final results are (all numbers annualized):')
display(results.T)

# %% [markdown]
# ---

# %% [markdown]
# # To do, for advanced econometrics

# %%
# GRS results 
from numpy.linalg import inv
from scipy.stats import f

def GRS(alpha, resids, mu):
    # GRS test statistic
    # N assets, L factors, and T time points
    # alpha is a Nx1 vector of intercepts of the time-series regressions,
    # resids is a TxN matrix of residuals,
    # mu is a TxL matrix of factor returns --> the average returns 
    T, N = resids.shape
    L = mu.shape[1]
    mu_mean = np.nanmean(mu, axis=0)
    cov_resids = np.matmul(resids.T, resids) / (T-L-1)
    cov_fac = np.matmul(np.array(mu - np.nanmean(mu, axis=0)).T, np.array(mu - np.nanmean(mu, axis=0))) / T-1
    GRS = (T / N) * ((T - N - L) / (T - L - 1)) * ((np.matmul(np.matmul(alpha.T, inv(cov_resids)), alpha)) / (1 + (np.matmul(np.matmul(mu_mean.T, inv(cov_fac)), mu_mean))))
    pVal = 1-f.cdf(GRS, N, T - N - L)
    return GRS, pVal

# %%
GRS(results['Alpha'].values, matrix_res, matrix_factor_returns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-179-bd95a7067730> in <module>
# ----> 1 GRS(results['Alpha'].values, matrix_res, matrix_factor_returns)
#
# <ipython-input-107-dda72a92bba2> in GRS(alpha, resids, mu)
#      14     cov_resids = np.matmul(resids.T, resids) / (T-L-1)
#      15     cov_fac = np.matmul(np.array(mu - np.nanmean(mu, axis=0)).T, np.array(mu - np.nanmean(mu, axis=0))) / T-1
# ---> 16     GRS = (T / N) * ((T - N - L) / (T - L - 1)) * ((np.matmul(np.matmul(alpha.T, inv(cov_resids)), alpha)) / (1 + (np.matmul(np.matmul(mu_mean.T, inv(cov_fac)), mu_mean))))
#      17     pVal = 1-f.cdf(GRS, N, T - N - L)
#      18     return GRS, pVal
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 251 is different from 10)

# %%
alpha, resids, mu = results['Alpha'].values, matrix_res, matrix_factor_returns

T, N = resids.shape
L = mu.shape[1]
mu_mean = np.nanmean(mu, axis=0)
cov_resids = np.matmul(resids.T, resids) / (T-L-1)
cov_fac = np.matmul(np.array(mu - np.nanmean(mu, axis=0)).T, np.array(mu - np.nanmean(mu, axis=0))) / T-1
GRS_1 = (T / N) * ((T - N - L) / (T - L - 1))  
#GRS_2 = ((np.matmul(np.matmul(alpha.T, inv(cov_resids)), alpha)))


resids.shape
# Out:
# (10, 251)

# %% [markdown]
# # That's it. Now it's up to you to study the code and practice with it!

# %%
"""
  ____        _   _                   _                                                    
 |  _ \ _   _| |_| |__   ___  _ __   (_)___    __ ___      _____  ___  ___  _ __ ___   ___ 
 | |_) | | | | __| '_ \ / _ \| '_ \  | / __|  / _` \ \ /\ / / _ \/ __|/ _ \| '_ ` _ \ / _ \
 |  __/| |_| | |_| | | | (_) | | | | | \__ \ | (_| |\ V  V /  __/\__ \ (_) | | | | | |  __/
 |_|    \__, |\__|_| |_|\___/|_| |_| |_|___/  \__,_| \_/\_/ \___||___/\___/|_| |_| |_|\___|
        |___/                                                                              
        
"""
print('End of notebook.')

# %% [markdown]
# ---
